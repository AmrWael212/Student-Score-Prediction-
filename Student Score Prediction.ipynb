# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import warnings 
import seaborn as sns 
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'StudentPerformanceFactors.csv')

# %%
data.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
data.tail()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                  1          High
# ...

# %%
data.sample(5)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 3915             19          71               Medium              Medium
# 4356             21          64               Medium              Medium
# 1457             22          75                 High                High
# 2475             24          99                 High              Medium
# 4735             26          61                 High              Medium
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 3915                        Yes            7               91
# 4356                         No            9               82
# 1457                        Yes            9               66
# 2475                        Yes            7               69
# 4735                        Yes            8               70
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 3915           Medium             Yes                  3          High
# ...

# %%
data.shape
# Out:
# (6607, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
data['Parental_Education_Level'].mode()
# Out:
# 0    High School
# Name: Parental_Education_Level, dtype: object

# %%
data['Distance_from_Home'].mode()
# Out:
# 0    Near
# Name: Distance_from_Home, dtype: object

# %%
data['Teacher_Quality'].mode()
# Out:
# 0    Medium
# Name: Teacher_Quality, dtype: object

# %%
data.Teacher_Quality.fillna("Medium",inplace=True)

# %%
data.Distance_from_Home.fillna("Near",inplace=True)

# %%
data.Parental_Education_Level.fillna("High School",inplace=True)

# %%
data.isna().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
data.shape
# Out:
# (6607, 20)

# %%
numeric_cols = data.select_dtypes(include='number').columns
outlier_indices = set()
for col in numeric_cols:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[col] < lower_bound) | (data[col] > upper_bound)].index
    outlier_indices.update(outliers)
data = data.drop(index=outlier_indices).reset_index(drop=True)

# %%
data.shape
# Out:
# (6054, 20)

# %%
data.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6054.000000  6054.000000  6054.000000      6054.000000
# mean       20.019326    79.972580     7.034357        75.111827
# std         5.776193    11.498579     1.469827        14.355942
# min         4.000000    60.000000     4.000000        50.000000
# 25%        16.000000    70.000000     6.000000        63.000000
# 50%        20.000000    80.000000     7.000000        75.000000
# 75%        24.000000    90.000000     8.000000        87.750000
# max        36.000000   100.000000    10.000000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6054.000000        6054.000000  6054.000000
# mean            1.293360           2.961843    66.981500
# std             0.983676           1.029563     3.225434
# min             0.000000           0.000000    59.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
data['Exam_Score'].describe()
# Out:
# count    6054.000000
# mean       66.981500
# std         3.225434
# min        59.000000
# 25%        65.000000
# 50%        67.000000
# 75%        69.000000
# max        75.000000
# Name: Exam_Score, dtype: float64

# %%
len(data)
# Out:
# 6053

# %%
data['Hours_Studied'].describe()
# Out:
# count    6053.000000
# mean       20.018999
# std         5.776614
# min         4.000000
# 25%        16.000000
# 50%        20.000000
# 75%        24.000000
# max        36.000000
# Name: Hours_Studied, dtype: float64

# %%
data['Attendance'].describe()
# Out:
# count    6053.000000
# mean       79.974888
# std        11.498126
# min        60.000000
# 25%        70.000000
# 50%        80.000000
# 75%        90.000000
# max       100.000000
# Name: Attendance, dtype: float64

# %%
data['Parental_Involvement'].value_counts()
# Out:
# Parental_Involvement
# Medium    3097
# High      1745
# Low       1211
# Name: count, dtype: int64

# %%
data['Access_to_Resources'].value_counts()
# Out:
# Access_to_Resources
# Medium    3048
# High      1804
# Low       1201
# Name: count, dtype: int64

# %%
data['Extracurricular_Activities'].value_counts()
# Out:
# Extracurricular_Activities
# Yes    3605
# No     2448
# Name: count, dtype: int64

# %%
data['Sleep_Hours'].describe()
# Out:
# count    6053.000000
# mean        7.034859
# std         1.469431
# min         4.000000
# 25%         6.000000
# 50%         7.000000
# 75%         8.000000
# max        10.000000
# Name: Sleep_Hours, dtype: float64

# %%
data['Previous_Scores'].describe()
# Out:
# count    6053.000000
# mean       75.108541
# std        14.354851
# min        50.000000
# 25%        63.000000
# 50%        75.000000
# 75%        87.000000
# max       100.000000
# Name: Previous_Scores, dtype: float64

# %%
data['Motivation_Level'].value_counts()
# Out:
# Motivation_Level
# Medium    3076
# Low       1775
# High      1202
# Name: count, dtype: int64

# %%
data['Internet_Access'].value_counts()
# Out:
# Internet_Access
# Yes    5591
# No      462
# Name: count, dtype: int64

# %%
data['Tutoring_Sessions'].describe()
# Out:
# count    6053.000000
# mean        1.293408
# std         0.983750
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         3.000000
# Name: Tutoring_Sessions, dtype: float64

# %%
data['Family_Income'].value_counts()
# Out:
# Family_Income
# Medium    2458
# Low       2440
# High      1155
# Name: count, dtype: int64

# %%
data['Teacher_Quality'].value_counts()
# Out:
# Teacher_Quality
# Medium    3668
# High      1790
# Low        595
# Name: count, dtype: int64

# %%
data['School_Type'].value_counts()
# Out:
# School_Type
# Public     4214
# Private    1839
# Name: count, dtype: int64

# %%
data['Peer_Influence'].value_counts()
# Out:
# Peer_Influence
# Positive    2415
# Neutral     2378
# Negative    1260
# Name: count, dtype: int64

# %%
data['Physical_Activity'].describe()
# Out:
# count    6053.000000
# mean        2.961507
# std         1.029315
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         6.000000
# Name: Physical_Activity, dtype: float64

# %%
data['Parental_Education_Level'].value_counts()
# Out:
# Parental_Education_Level
# High School     3040
# College         1812
# Postgraduate    1201
# Name: count, dtype: int64

# %%
data['Distance_from_Home'].value_counts()
# Out:
# Distance_from_Home
# Near        3621
# Moderate    1834
# Far          598
# Name: count, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      3490
# Female    2563
# Name: count, dtype: int64

# %%
data['Exam_Score'].describe()
# Out:
# count    6053.000000
# mean       66.981827
# std         3.225600
# min        59.000000
# 25%        65.000000
# 50%        67.000000
# 75%        69.000000
# max        75.000000
# Name: Exam_Score, dtype: float64

# %%
data.groupby('Gender').Exam_Score.mean()
# Out:
# Gender
# Female    66.930940
# Male      67.019198
# Name: Exam_Score, dtype: float64

# %%
data.groupby('Gender').Sleep_Hours.mean()
# Out:
# Gender
# Female    7.055014
# Male      7.020057
# Name: Sleep_Hours, dtype: float64

# %%
data.groupby('Gender').Attendance.mean()
# Out:
# Gender
# Female    79.710496
# Male      80.169054
# Name: Attendance, dtype: float64

# %%
data.groupby('Gender').Previous_Scores.mean()
# Out:
# Gender
# Female    75.026141
# Male      75.169054
# Name: Previous_Scores, dtype: float64

# %%
data.groupby('Gender').Tutoring_Sessions.mean()
# Out:
# Gender
# Female    1.307452
# Male      1.283095
# Name: Tutoring_Sessions, dtype: float64

# %%
data.groupby('Distance_from_Home').Exam_Score.mean()
# Out:
# Distance_from_Home
# Far         66.229097
# Moderate    66.768811
# Near        67.214029
# Name: Exam_Score, dtype: float64

# %%
data.groupby('Distance_from_Home').Previous_Scores.mean()
# Out:
# Distance_from_Home
# Far         75.285953
# Moderate    74.946565
# Near        75.161281
# Name: Previous_Scores, dtype: float64

# %%
data.groupby('School_Type').Hours_Studied.mean()
# Out:
# School_Type
# Private    20.041327
# Public     20.009255
# Name: Hours_Studied, dtype: float64

# %%
pd.crosstab(data['Distance_from_Home'],data['Gender'])
# Out:
# Gender              Female  Male
# Distance_from_Home
# Far                    255   343
# Moderate               777  1057
# Near                  1531  2090

# %%
pd.crosstab(data['Parental_Education_Level'],data['Gender'])
# Out:
# Gender                    Female  Male
# Parental_Education_Level
# College                      790  1022
# High School                 1266  1774
# Postgraduate                 507   694

# %%
pd.crosstab(data['Parental_Education_Level'],data['Parental_Involvement'])
# Out:
# Parental_Involvement      High  Low  Medium
# Parental_Education_Level
# College                    536  371     905
# High School                872  594    1574
# Postgraduate               337  246     618

# %%
plt.hist(data['Exam_Score'],bins=20)
plt.title('Scores')
plt.show()

# %%
plt.scatter(data['Exam_Score'],data['Hours_Studied'],color='red')
plt.xlabel('Score')
plt.ylabel('Study hours')
plt.title('Score/Study Hours')
plt.show()

# %%
plt.scatter(data['Exam_Score'],data['Attendance'],color='green')
plt.xlabel('Score')
plt.ylabel('Class Attendance')
plt.title('Score/Attendance')
plt.show()

# %%
sns.boxplot(data=data,x='Exam_Score',y='Extracurricular_Activities',color='yellow')
plt.title('Score/Activity')
# Out:
# Text(0.5, 1.0, 'Score/Activity')

# %%
sns.boxplot(data=data,x='Attendance',y='Motivation_Level',color='Violet')
plt.title('Attendance/Motivation')
# Out:
# Text(0.5, 1.0, 'Attendance/Motivation')

# %%
sns.pairplot(data)

# %%
plt.hist(data['Hours_Studied'],bins=20,color='red')
plt.title('Hours Studied')
plt.show()

# %%
sns.kdeplot(data=data,x='Attendance')
# Out:
# <Axes: xlabel='Attendance', ylabel='Density'>

# %%
sns.kdeplot(data)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.violinplot(data=data,x='Access_to_Resources',y='Peer_Influence')
# Out:
# <Axes: xlabel='Access_to_Resources', ylabel='Peer_Influence'>

# %%
plt.pie(data['Gender'].value_counts(),autopct='%.2f%%',labels=['Male','Female'])
plt.title('Gender Percentage')
# Out:
# Text(0.5, 1.0, 'Gender Percentage')

# %%
plt.pie(data['Parental_Involvement'].value_counts()	,autopct='%.2f%%',labels=['Medium','High','Low'],explode=[0.1,0,0],shadow=True)
plt.title("Parental Involvement")
# Out:
# Text(0.5, 1.0, 'Parental Involvement')

# %%
plt.pie(data['Family_Income'].value_counts(),autopct='%.2f%%',labels=['Medium','High','Low'],explode=[0.1,0,0],shadow=True)
plt.title("Family Income")
# Out:
# Text(0.5, 1.0, 'Family Income')

# %%
sns.pairplot(data[['Exam_Score','Hours_Studied','Attendance']])

# %%
sns.boxplot(data=data,x='Exam_Score',y='Motivation_Level',color='Pink')
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Motivation_Level'>

# %%
sns.scatterplot(data=data,x='Previous_Scores',y='Exam_Score',color='purple')
plt.title('Exam Score/Previous Score')
# Out:
# Text(0.5, 1.0, 'Exam Score/Previous Score')

# %%
data.corr(numeric_only=True)
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied           1.000000   -0.030607     0.011602         0.014244
# Attendance             -0.030607    1.000000    -0.019410        -0.026880
# Sleep_Hours             0.011602   -0.019410     1.000000        -0.017891
# Previous_Scores         0.014244   -0.026880    -0.017891         1.000000
# Tutoring_Sessions      -0.012088    0.005925    -0.005362        -0.024475
# Physical_Activity      -0.003684   -0.031271     0.003837        -0.012298
# Exam_Score              0.500865    0.682238    -0.009314         0.198954
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.012088          -0.003684    0.500865
# Attendance                  0.005925          -0.031271    0.682238
# Sleep_Hours                -0.005362           0.003837   -0.009314
# Previous_Scores            -0.024475          -0.012298    0.198954
# ...

# %%
sns.heatmap(data.corr(numeric_only=True),annot=True)
plt.title('Heatmap For Coorelation Of Numerical Only')
# Out:
# Text(0.5, 1.0, 'Heatmap For Coorelation Of Numerical Only')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
from sklearn.preprocessing import OneHotEncoder

# %%
X=data.drop('Exam_Score',axis=1)

# %%
y=data['Exam_Score']

# %%
X=pd.get_dummies(X).astype(int)
x_train,x_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
X
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0                23          84            7               73
# 1                19          64            8               59
# 2                24          98            7               91
# 3                29          89            8               98
# 4                19          92            6               65
# ...             ...         ...          ...              ...
# 6048             25          69            7               76
# 6049             23          76            8               81
# 6050             20          90            6               65
# 6051             10          86            6               91
# 6052             15          67            9               94
#
#       Tutoring_Sessions  Physical_Activity  Parental_Involvement_High  \
# 0                     0                  3                          0
# 1                     2                  4                          0
# ...

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
model.score(x_train,y_train)
# Out:
# 0.9900491386084175

# %%
model.score(x_test,y_test)
# Out:
# 0.988576615358215

# %%
r2_score(y_test,y_pred)
# Out:
# 0.988576615358215

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.27916620052711066

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.1115963870842303

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='steelblue', alpha=0.6, edgecolors='k')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)  # perfect prediction line
plt.xlabel('Actual Exam Scores')
plt.ylabel('Predicted Exam Scores')
plt.title('Actual vs Predicted Exam Scores')
plt.grid(True)
plt.tight_layout()
plt.show()
